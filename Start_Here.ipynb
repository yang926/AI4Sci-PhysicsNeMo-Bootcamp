# %% [markdown]
# # AI4Sci 실습 시작
#
# [전체 실습 순서와 실행 안내](ai4sci/README.md)를 열고 [환경 확인](ai4sci/00_환경확인.ipynb)을 진행합니다.
#
# 아래 순서대로 PhysicsNeMo 소개, Training Lab 1–4, Challenge 1–4를 진행합니다. 각 챌린지는 Level 1부터 차례로 수행합니다.
#
# 노트북의 설명을 읽고, 안내된 Python 파일을 수정·저장한 뒤 실행 셀을 실행합니다. 기초 Lab에서는 준비된 코드를 읽고 실행하고, Challenge에서는 `FIXME`를 직접 완성합니다.

# %% [markdown]
# # Welcome to PhysicsNeMo training Bootcamp!
#
# ---
#
# This Bootcamp will provide researchers hands-on approaches on how to use NVIDIA PhysicsNeMo, a framework that combines physics and partial differential equations (PDEs) with artificial intelligence (AI) to build robust models. Participants will also learn about the differences between Physics-driven and Data-driven approaches to AI. In addition, the Bootcamp will provide hands-on experience with visualizing the results of physics simulations using ParaView.
#
#
# ## PhysicsNeMo:
#
#
# - [Getting started with PhysicsNeMo](tutorial/introduction/Getting_Started_PhysicsNeMo.ipynb)
#     - [Introduction to PhysicsNeMo](tutorial/introduction/Getting_Started_PhysicsNeMo.ipynb#Introduction-to-PhysicsNeMo)
#     - [Physics-Informed approach vs Data-driven approach to neural networks](tutorial/introduction/Getting_Started_PhysicsNeMo.ipynb#Physics-Informed-approach-vs-Data-driven-approach-to-neural-networks)
#
#
#
#
# ### 2 Hours of Training Labs
#
# 1. [Introduction to Physics-Informed Neural Networks (PINNs)](tutorial/introduction/Introductory_Notebook.ipynb)
#     - [Neural Network Solver Methodology](tutorial/introduction/Introductory_Notebook.ipynb#Neural-Network-Solver-Methodology)
#     - [Parameterized Problems](tutorial/introduction/Introductory_Notebook.ipynb#Parameterized-Problems)
#     - [Inverse Problems](tutorial/introduction/Introductory_Notebook.ipynb#Inverse-Problems)
#
#
# 2. [Solving ODEs with PhysicsNeMo](tutorial/projectile/Getting_Started_Projectile.ipynb)
#     - [Simulating the Projectile Motion ODE](tutorial/projectile/Getting_Started_Projectile.ipynb#Simulating-the-Projectile-Motion-ODE)
#     - [Introduction to ParaView](tutorial/projectile/Getting_Started_Projectile.ipynb#Introduction-to-ParaView)
#
#
# 3. [From ODEs to PDEs - Diffusion Problems](tutorial/diffusion_1d/Diffusion_Problem_Notebook.ipynb)
#     - [Steady State 1D Diffusion in a Composite Bar](tutorial/diffusion_1d/Diffusion_Problem_Notebook.ipynb#Steady-State-1D-Diffusion-in-a-Composite-Bar-using-PINNs)
#     - [Parameterized 1D Diffusion of Composite Bar](tutorial/diffusion_1d/Diffusion_Problem_Notebook.ipynb#Parameterized-1D-Diffusion-of-Composite-Bar)
#
#
# 4. [Advanced PDE Systems](tutorial/navier_stokes/Weather-forecasting-navier-stokes.ipynb)
#     - [Forecasting weather at sea level using Navier Stokes equation](tutorial/navier_stokes/Weather-forecasting-navier-stokes.ipynb#Forecasting-Weather-using-Navier-Stokes-PDE)
#
#
# We have seen some hands-on examples on Physics informed approach, let us now use PhysicsNeMo to solve challenges.
#
# ### 4 Hours of Challenges
#
#
# 1. [Advanced Wave Dynamics](challenge/wave/Advanced_Wave_Dynamics.ipynb)
#     - [Level 1 Basic 2D wave equation](challenge/wave/Advanced_Wave_Dynamics.ipynb#Level-1-Basic-2D-wave-equation)
#     - [Level 2 Add variable wave speed](challenge/wave/Advanced_Wave_Dynamics.ipynb#Level-2-Variable-Wave-Speed)
#     - [Level 3 Multiple sources and complex boundaries](challenge/wave/Advanced_Wave_Dynamics.ipynb#Level-3-Complex-Boundaries-and-Circular-Domain)
#
#
# 2. [Fluid-Structure Interaction](challenge/fuild/Fluid_Structure_Interaction.ipynb)
#     - [Level 1 2D flow](challenge/fuild/Fluid_Structure_Interaction.ipynb#Level-1-2D-flow)
#     - [Level 2 Multiple Blocks in Channel](challenge/fuild/Fluid_Structure_Interaction.ipynb#Level-2-Multiple-Blocks-in-Channel)
#     - [Level 3 Time-Dependent Flow](challenge/fuild/Fluid_Structure_Interaction.ipynb#Level-3-Time-Dependent-Flow)
#
#
# 3. [Multi-Physics Climate Modeling](challenge/climate/Multi-Physics_Climate_Modeling.ipynb)
#     - [Level 1 Simple Atmosphere Model](challenge/climate/Multi-Physics_Climate_Modeling.ipynb#Level-1-Simple-Atmosphere-Model)
#     - [Level 2 Coupled Atmosphere–Ocean System](challenge/climate/Multi-Physics_Climate_Modeling.ipynb#Level-2-Coupled-Atmosphere-Ocean-System)
#
#
# 4. [Advanced Neural Operators](challenge/neural_operator/Advanced_Neural_Operators.ipynb)
#     - [Level 1 Fourier Neural Operator](challenge/neural_operator/Advanced_Neural_Operators.ipynb#Level-1-Fourier-Neural-Operator)
#     - [Level 2 Adaptive Fourier Neural Operator](challenge/neural_operator/Advanced_Neural_Operators.ipynb#Level-2-Adaptive-Fourier-Neural-Operator)
#     - [Level 3 Physics-Informed Neural Operator](challenge/neural_operator/Advanced_Neural_Operators.ipynb#Level-3-Physics-Informed-Neural-Operator)

# %% [markdown]
# ---
#
# Don't forget to check out additional [Open Hackathons Resources](https://www.openhackathons.org/s/technical-resources) and join our [OpenACC and Hackathons Slack Channel](https://www.openacc.org/community#slack) to share your experience and get more help from the community.
#
# ---
#
# # Licensing
#
# Copyright © 2026 OpenACC-Standard.org. This material is released by OpenACC-Standard.org, in collaboration with NVIDIA Corporation, under the Creative Commons Attribution 4.0 International (CC BY 4.0). These materials may include references to hardware and software developed by other entities; all applicable licensing and copyrights apply.
